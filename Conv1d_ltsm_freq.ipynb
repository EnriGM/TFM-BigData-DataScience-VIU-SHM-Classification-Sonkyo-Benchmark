# %%
import numpy as np

x = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\x_for_ltsm.npy")
y = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\y_for_ltsm.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

signal_x_train = x_train[:, :-1]
signal_x_test = x_test[:, :-1]
temp_x_train = x_train[:, -1].reshape(-1, 1)
temp_x_test = x_test[:, -1].reshape(-1, 1)

sc_temp = StandardScaler()
temp_x_train = sc_temp.fit_transform(temp_x_train)
temp_x_test = sc_temp.transform(temp_x_test)

sc = StandardScaler()
train_shape = signal_x_train.shape

signal_x_train = signal_x_train.reshape(train_shape[0]*train_shape[1])
signal_x_train = sc.fit_transform(signal_x_train.reshape(-1, 1))
signal_x_train = signal_x_train.reshape(train_shape[0], train_shape[1])

test_shape = signal_x_test.shape
signal_x_test = signal_x_test.reshape(test_shape[0]*test_shape[1])
signal_x_test = sc.transform(signal_x_test.reshape(-1, 1))
signal_x_test = signal_x_test.reshape(test_shape[0], test_shape[1])

# %%
import tensorflow as tf
from tensorflow import keras


time_input = keras.layers.Input(shape=(129, 1))
temp_input = keras.layers.Input(shape=(1,))

conv_1 = keras.layers.Conv1D(filters=32, kernel_size=32, strides=2, activation='relu')(time_input)

conv_3 = keras.layers.Conv1D(filters=64, kernel_size=16, strides=2, activation='relu')(conv_1)

conv_4 = keras.layers.Conv1D(filters=128, kernel_size=8, strides=2, activation='relu')(conv_3)

lstm = keras.layers.LSTM(128)(conv_4)

dense0 = keras.layers.Dense(1, activation="relu")(temp_input)

merged = keras.layers.Concatenate(axis=1)([lstm, dense0])

dense_1 = keras.layers.Dense(128, activation='relu')(merged)
#drop_1 = keras.layers.Dropout(0.1)(dense_1)
dense_2 = keras.layers.Dense(64, activation='relu')(dense_1)
#drop_2 = keras.layers.Dropout(0.1)(dense_2)
output = keras.layers.Dense(13, activation='softmax')(dense_2)

model = keras.models.Model(inputs=[time_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 129, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 49, 32)       1056        ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 17, 64)       32832       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 5, 128)       65664       ['conv1d_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  lstm (LSTM)                    (None, 128)          131584      ['conv1d_2[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 129)          0           ['lstm[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16640       ['concatenate[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 13)           845         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 256,879
# Trainable params: 256,879
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="acc")
    ],
)

# %%
batch_size = 128
num_epochs = 500

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)
# Fit the model.

history = model.fit(
    x=[signal_x_train, temp_x_train],
    y=y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
# Out:
# Epoch 1/500
# 1193/1193 - 11s - loss: 0.9750 - acc: 0.6562 - val_loss: 0.5348 - val_acc: 0.7946 - lr: 1.0000e-04 - 11s/epoch - 9ms/step
# Epoch 2/500
# 1193/1193 - 7s - loss: 0.4492 - acc: 0.8307 - val_loss: 0.3717 - val_acc: 0.8631 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 3/500
# 1193/1193 - 7s - loss: 0.3411 - acc: 0.8738 - val_loss: 0.3048 - val_acc: 0.8884 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 4/500
# 1193/1193 - 7s - loss: 0.2824 - acc: 0.8955 - val_loss: 0.2518 - val_acc: 0.9089 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 5/500
# 1193/1193 - 8s - loss: 0.2433 - acc: 0.9101 - val_loss: 0.2255 - val_acc: 0.9159 - lr: 1.0000e-04 - 8s/epoch - 6ms/step
# Epoch 6/500
# 1193/1193 - 7s - loss: 0.2176 - acc: 0.9198 - val_loss: 0.2106 - val_acc: 0.9219 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 7/500
# 1193/1193 - 7s - loss: 0.1985 - acc: 0.9266 - val_loss: 0.1853 - val_acc: 0.9325 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 8/500
# 1193/1193 - 7s - loss: 0.1812 - acc: 0.9338 - val_loss: 0.1659 - val_acc: 0.9397 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 9/500
# 1193/1193 - 8s - loss: 0.1693 - acc: 0.9382 - val_loss: 0.1675 - val_acc: 0.9385 - lr: 1.0000e-04 - 8s/epoch - 6ms/step
# Epoch 10/500
# 1193/1193 - 7s - loss: 0.1591 - acc: 0.9420 - val_loss: 0.1571 - val_acc: 0.9427 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 11/500
# 1193/1193 - 7s - loss: 0.1505 - acc: 0.9455 - val_loss: 0.1681 - val_acc: 0.9369 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 12/500
# 1193/1193 - 7s - loss: 0.1431 - acc: 0.9475 - val_loss: 0.1427 - val_acc: 0.9479 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 13/500
# 1193/1193 - 7s - loss: 0.1352 - acc: 0.9504 - val_loss: 0.1295 - val_acc: 0.9526 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 14/500
# 1193/1193 - 7s - loss: 0.1312 - acc: 0.9521 - val_loss: 0.1450 - val_acc: 0.9469 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 15/500
# 1193/1193 - 7s - loss: 0.1276 - acc: 0.9533 - val_loss: 0.1237 - val_acc: 0.9548 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 16/500
# 1193/1193 - 7s - loss: 0.1198 - acc: 0.9565 - val_loss: 0.1222 - val_acc: 0.9556 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 17/500
# 1193/1193 - 7s - loss: 0.1182 - acc: 0.9565 - val_loss: 0.1504 - val_acc: 0.9449 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 18/500
# 1193/1193 - 7s - loss: 0.1136 - acc: 0.9581 - val_loss: 0.1107 - val_acc: 0.9597 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 19/500
# 1193/1193 - 7s - loss: 0.1106 - acc: 0.9599 - val_loss: 0.1525 - val_acc: 0.9444 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 20/500
# 1193/1193 - 7s - loss: 0.1074 - acc: 0.9603 - val_loss: 0.1235 - val_acc: 0.9539 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 21/500
# 1193/1193 - 7s - loss: 0.1035 - acc: 0.9621 - val_loss: 0.1062 - val_acc: 0.9611 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 22/500
# 1193/1193 - 7s - loss: 0.1016 - acc: 0.9627 - val_loss: 0.1115 - val_acc: 0.9585 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 23/500
# 1193/1193 - 7s - loss: 0.0991 - acc: 0.9638 - val_loss: 0.1008 - val_acc: 0.9629 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 24/500
# 1193/1193 - 7s - loss: 0.0962 - acc: 0.9645 - val_loss: 0.1005 - val_acc: 0.9631 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 25/500
# 1193/1193 - 7s - loss: 0.0959 - acc: 0.9648 - val_loss: 0.1009 - val_acc: 0.9620 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 26/500
# 1193/1193 - 7s - loss: 0.0925 - acc: 0.9657 - val_loss: 0.0969 - val_acc: 0.9644 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 27/500
# 1193/1193 - 7s - loss: 0.0901 - acc: 0.9663 - val_loss: 0.0954 - val_acc: 0.9653 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 28/500
# 1193/1193 - 7s - loss: 0.0876 - acc: 0.9674 - val_loss: 0.0983 - val_acc: 0.9637 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 29/500
# 1193/1193 - 7s - loss: 0.0868 - acc: 0.9681 - val_loss: 0.1005 - val_acc: 0.9632 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 30/500
# 1193/1193 - 7s - loss: 0.0856 - acc: 0.9682 - val_loss: 0.0882 - val_acc: 0.9677 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 31/500
# 1193/1193 - 7s - loss: 0.0819 - acc: 0.9698 - val_loss: 0.0868 - val_acc: 0.9680 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 32/500
# 1193/1193 - 7s - loss: 0.0800 - acc: 0.9704 - val_loss: 0.0854 - val_acc: 0.9691 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 33/500
# 1193/1193 - 7s - loss: 0.0792 - acc: 0.9710 - val_loss: 0.0876 - val_acc: 0.9672 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 34/500
# 1193/1193 - 7s - loss: 0.0780 - acc: 0.9711 - val_loss: 0.0932 - val_acc: 0.9653 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 35/500
# 1193/1193 - 7s - loss: 0.0746 - acc: 0.9724 - val_loss: 0.0982 - val_acc: 0.9649 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 36/500
# 1193/1193 - 7s - loss: 0.0747 - acc: 0.9727 - val_loss: 0.0848 - val_acc: 0.9686 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 37/500
# 1193/1193 - 7s - loss: 0.0716 - acc: 0.9737 - val_loss: 0.0863 - val_acc: 0.9683 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 38/500
# 1193/1193 - 7s - loss: 0.0709 - acc: 0.9735 - val_loss: 0.0828 - val_acc: 0.9702 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 39/500
# 1193/1193 - 7s - loss: 0.0694 - acc: 0.9745 - val_loss: 0.1079 - val_acc: 0.9613 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 40/500
# 1193/1193 - 7s - loss: 0.0676 - acc: 0.9747 - val_loss: 0.1013 - val_acc: 0.9636 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 41/500
# 1193/1193 - 7s - loss: 0.0678 - acc: 0.9750 - val_loss: 0.0887 - val_acc: 0.9681 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 42/500
# 1193/1193 - 7s - loss: 0.0653 - acc: 0.9756 - val_loss: 0.0849 - val_acc: 0.9691 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 43/500
# 1193/1193 - 7s - loss: 0.0655 - acc: 0.9754 - val_loss: 0.0808 - val_acc: 0.9711 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 44/500
# 1193/1193 - 7s - loss: 0.0658 - acc: 0.9757 - val_loss: 0.0906 - val_acc: 0.9662 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 45/500
# 1193/1193 - 7s - loss: 0.0632 - acc: 0.9766 - val_loss: 0.0921 - val_acc: 0.9667 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 46/500
# 1193/1193 - 7s - loss: 0.0623 - acc: 0.9768 - val_loss: 0.0784 - val_acc: 0.9712 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 47/500
# 1193/1193 - 7s - loss: 0.0600 - acc: 0.9778 - val_loss: 0.0850 - val_acc: 0.9696 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 48/500
# 1193/1193 - 7s - loss: 0.0613 - acc: 0.9774 - val_loss: 0.0896 - val_acc: 0.9674 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 49/500
# 1193/1193 - 7s - loss: 0.0589 - acc: 0.9783 - val_loss: 0.0896 - val_acc: 0.9674 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 50/500
# 1193/1193 - 7s - loss: 0.0585 - acc: 0.9783 - val_loss: 0.0901 - val_acc: 0.9681 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 51/500
# 1193/1193 - 7s - loss: 0.0561 - acc: 0.9791 - val_loss: 0.0737 - val_acc: 0.9728 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 52/500
# 1193/1193 - 7s - loss: 0.0564 - acc: 0.9789 - val_loss: 0.0752 - val_acc: 0.9721 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 53/500
# 1193/1193 - 7s - loss: 0.0550 - acc: 0.9797 - val_loss: 0.0873 - val_acc: 0.9690 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 54/500
# 1193/1193 - 7s - loss: 0.0549 - acc: 0.9796 - val_loss: 0.0797 - val_acc: 0.9718 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 55/500
# 1193/1193 - 7s - loss: 0.0535 - acc: 0.9803 - val_loss: 0.0771 - val_acc: 0.9722 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 56/500
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1193/1193 - 7s - loss: 0.0526 - acc: 0.9805 - val_loss: 0.0871 - val_acc: 0.9691 - lr: 1.0000e-04 - 7s/epoch - 6ms/step
# Epoch 57/500
# 1193/1193 - 8s - loss: 0.0432 - acc: 0.9846 - val_loss: 0.0725 - val_acc: 0.9742 - lr: 5.0000e-05 - 8s/epoch - 6ms/step
# Epoch 58/500
# 1193/1193 - 7s - loss: 0.0435 - acc: 0.9841 - val_loss: 0.0729 - val_acc: 0.9740 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 59/500
# 1193/1193 - 7s - loss: 0.0421 - acc: 0.9847 - val_loss: 0.0790 - val_acc: 0.9720 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 60/500
# 1193/1193 - 8s - loss: 0.0422 - acc: 0.9848 - val_loss: 0.0698 - val_acc: 0.9750 - lr: 5.0000e-05 - 8s/epoch - 6ms/step
# Epoch 61/500
# 1193/1193 - 7s - loss: 0.0411 - acc: 0.9848 - val_loss: 0.0714 - val_acc: 0.9748 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 62/500
# 1193/1193 - 7s - loss: 0.0404 - acc: 0.9856 - val_loss: 0.0705 - val_acc: 0.9757 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 63/500
# 1193/1193 - 7s - loss: 0.0400 - acc: 0.9856 - val_loss: 0.0725 - val_acc: 0.9747 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 64/500
# 1193/1193 - 7s - loss: 0.0392 - acc: 0.9857 - val_loss: 0.0722 - val_acc: 0.9742 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 65/500
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1193/1193 - 7s - loss: 0.0390 - acc: 0.9859 - val_loss: 0.0766 - val_acc: 0.9729 - lr: 5.0000e-05 - 7s/epoch - 6ms/step
# Epoch 66/500
# 1193/1193 - 8s - loss: 0.0341 - acc: 0.9881 - val_loss: 0.0679 - val_acc: 0.9764 - lr: 2.5000e-05 - 8s/epoch - 6ms/step
# Epoch 67/500
# 1193/1193 - 7s - loss: 0.0335 - acc: 0.9883 - val_loss: 0.0677 - val_acc: 0.9762 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 68/500
# 1193/1193 - 7s - loss: 0.0333 - acc: 0.9883 - val_loss: 0.0679 - val_acc: 0.9767 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 69/500
# 1193/1193 - 7s - loss: 0.0330 - acc: 0.9884 - val_loss: 0.0684 - val_acc: 0.9766 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 70/500
# 1193/1193 - 7s - loss: 0.0327 - acc: 0.9885 - val_loss: 0.0719 - val_acc: 0.9759 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 71/500
# 1193/1193 - 7s - loss: 0.0324 - acc: 0.9884 - val_loss: 0.0707 - val_acc: 0.9760 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 72/500
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1193/1193 - 7s - loss: 0.0315 - acc: 0.9890 - val_loss: 0.0699 - val_acc: 0.9764 - lr: 2.5000e-05 - 7s/epoch - 6ms/step
# Epoch 73/500
# 1193/1193 - 8s - loss: 0.0294 - acc: 0.9902 - val_loss: 0.0687 - val_acc: 0.9772 - lr: 1.2500e-05 - 8s/epoch - 6ms/step
# Epoch 74/500
# 1193/1193 - 7s - loss: 0.0289 - acc: 0.9903 - val_loss: 0.0688 - val_acc: 0.9766 - lr: 1.2500e-05 - 7s/epoch - 6ms/step
# Epoch 75/500
# 1193/1193 - 7s - loss: 0.0290 - acc: 0.9900 - val_loss: 0.0682 - val_acc: 0.9768 - lr: 1.2500e-05 - 7s/epoch - 6ms/step
# Epoch 76/500
# 1193/1193 - 7s - loss: 0.0288 - acc: 0.9902 - val_loss: 0.0687 - val_acc: 0.9768 - lr: 1.2500e-05 - 7s/epoch - 6ms/step
# Epoch 77/500
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 1193/1193 - 7s - loss: 0.0285 - acc: 0.9903 - val_loss: 0.0689 - val_acc: 0.9770 - lr: 1.2500e-05 - 7s/epoch - 6ms/step

# %%
_, accuracy = model.evaluate([signal_x_test, temp_x_test], y_test)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 6s 4ms/step - loss: 0.0682 - acc: 0.9758
# Test accuracy: 97.58%

# %%
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
import matplotlib.pyplot as plt
metric = "acc"
plt.figure()
plt.plot(history.history[metric], label="train")
plt.plot(history.history["val_" + metric], label="val")
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend()
plt.show()
plt.close()
# Out:
# Test accuracy: 97.58%

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict([signal_x_test, temp_x_test])
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN1D_freq_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 4s 3ms/step

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\freq_all_std_force_quality\Conv1D_ltsm_freq.h5', save_format="h5")
