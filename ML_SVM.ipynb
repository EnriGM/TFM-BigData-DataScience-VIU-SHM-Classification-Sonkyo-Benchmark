# %% [markdown]
# K neightbours classifier time

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 10

param_dist = {"kernel": ['linear', 'poly', 'rbf', 'sigmoid']
              }

clf = SVC()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# C:\Users\AndreaEnrique\miniconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 2026-02-02 20:29:01.625478
# start random search
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....................kernel=linear;, score=0.263 total time=30.3min
# [CV 2/5] END .....................kernel=linear;, score=0.261 total time=29.1min
# [CV 3/5] END .....................kernel=linear;, score=0.262 total time=30.3min
# [CV 4/5] END .....................kernel=linear;, score=0.259 total time=34.3min
# [CV 5/5] END .....................kernel=linear;, score=0.261 total time=29.9min
# [CV 1/5] END .......................kernel=poly;, score=0.304 total time=42.9min
# [CV 2/5] END .......................kernel=poly;, score=0.307 total time=50.9min
# [CV 3/5] END .......................kernel=poly;, score=0.303 total time=52.1min
# [CV 4/5] END .......................kernel=poly;, score=0.304 total time=59.0min
# [CV 5/5] END .......................kernel=poly;, score=0.304 total time=63.7min
# [CV 1/5] END ........................kernel=rbf;, score=0.314 total time=31.8min
# [CV 2/5] END ........................kernel=rbf;, score=0.316 total time=31.5min
# [CV 3/5] END ........................kernel=rbf;, score=0.313 total time=31.7min
# [CV 4/5] END ........................kernel=rbf;, score=0.314 total time=31.5min
# [CV 5/5] END ........................kernel=rbf;, score=0.314 total time=31.5min
# [CV 1/5] END ....................kernel=sigmoid;, score=0.168 total time=25.4min
# [CV 2/5] END ....................kernel=sigmoid;, score=0.167 total time=26.5min
# [CV 3/5] END ....................kernel=sigmoid;, score=0.170 total time=24.4min
# [CV 4/5] END ....................kernel=sigmoid;, score=0.167 total time=25.3min
# [CV 5/5] END ....................kernel=sigmoid;, score=0.156 total time=24.2min
# {'kernel': 'rbf'}
# precision 0.31970992622401073
# 2026-02-03 09:09:19.934778

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"kernel": ['rbf'],
              "gamma": ['scale', 'auto']
              }

clf = SVC()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ...........gamma=scale, kernel=rbf;, score=0.314 total time=31.8min
# [CV 2/5] END ...........gamma=scale, kernel=rbf;, score=0.316 total time=31.5min
# [CV 3/5] END ...........gamma=scale, kernel=rbf;, score=0.313 total time=31.7min
# [CV 4/5] END ...........gamma=scale, kernel=rbf;, score=0.314 total time=31.5min
# [CV 5/5] END ...........gamma=scale, kernel=rbf;, score=0.314 total time=31.5min
# [CV 1/5] END ............gamma=auto, kernel=rbf;, score=0.314 total time=31.7min
# [CV 2/5] END ............gamma=auto, kernel=rbf;, score=0.317 total time=31.6min
# [CV 3/5] END ............gamma=auto, kernel=rbf;, score=0.314 total time=31.8min
# [CV 4/5] END ............gamma=auto, kernel=rbf;, score=0.314 total time=31.5min
# [CV 5/5] END ............gamma=auto, kernel=rbf;, score=0.313 total time=31.4min
# {'gamma': 'scale', 'kernel': 'rbf'}
# precision 0.31970992622401073

# %%
import pickle 

with open(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\time_all_std_force_quality\SVM_time.pickle', 'wb') as f:

    pickle.dump(model, f)

# %% [markdown]
# K neightbours classifier freq

# %%
import numpy as np

x = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\x_for_ml.npy")
y = np.load(r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\data_for_ml_all_std_force_quality_freq\y_for_ml.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import precision_score
from datetime import datetime

print(datetime.now())

n_iter_search = 10

param_dist = {"kernel": ['linear', 'poly', 'rbf', 'sigmoid']
              }

clf = SVC()
print("start random search")
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=n_iter_search,
    random_state=SEED, verbose=3)

random_search.fit(X_train, y_train)
print(random_search.best_params_)
model = random_search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
print(datetime.now())
# Out:
# 2026-02-04 18:04:46.097386
# start random search
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\AndreaEnrique\miniconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [CV 1/5] END .....................kernel=linear;, score=0.315 total time=27.1min
# [CV 2/5] END .....................kernel=linear;, score=0.319 total time=28.3min
# [CV 3/5] END .....................kernel=linear;, score=0.316 total time=27.0min
# [CV 4/5] END .....................kernel=linear;, score=0.316 total time=28.4min
# [CV 5/5] END .....................kernel=linear;, score=0.316 total time=26.9min
# [CV 1/5] END .......................kernel=poly;, score=0.366 total time=20.7min
# [CV 2/5] END .......................kernel=poly;, score=0.368 total time=20.6min
# [CV 3/5] END .......................kernel=poly;, score=0.362 total time=20.8min
# [CV 4/5] END .......................kernel=poly;, score=0.365 total time=20.6min
# [CV 5/5] END .......................kernel=poly;, score=0.364 total time=20.5min
# [CV 1/5] END ........................kernel=rbf;, score=0.390 total time=24.7min
# [CV 2/5] END ........................kernel=rbf;, score=0.394 total time=24.7min
# [CV 3/5] END ........................kernel=rbf;, score=0.388 total time=24.7min
# [CV 4/5] END ........................kernel=rbf;, score=0.392 total time=24.8min
# [CV 5/5] END ........................kernel=rbf;, score=0.389 total time=24.5min
# [CV 1/5] END ....................kernel=sigmoid;, score=0.182 total time=23.1min
# [CV 2/5] END ....................kernel=sigmoid;, score=0.178 total time=23.6min
# [CV 3/5] END ....................kernel=sigmoid;, score=0.182 total time=24.0min
# [CV 4/5] END ....................kernel=sigmoid;, score=0.181 total time=24.3min
# [CV 5/5] END ....................kernel=sigmoid;, score=0.168 total time=24.4min
# {'kernel': 'rbf'}
# precision 0.3975729376257545
# 2026-02-05 02:49:21.859003

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score
from sklearn.model_selection import GridSearchCV

param_dist = {"kernel": ['rbf'],
              "gamma": ['scale', 'auto']
              }

clf = SVC()
print("start random search")
search = GridSearchCV(clf, param_grid=param_dist, verbose=3)

search.fit(X_train, y_train)
print(search.best_params_)
model = search.best_estimator_
y_pred = model.predict(X_test)
print("precision", precision_score(y_test, y_pred, average="micro"))
# Out:
# start random search
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ...........gamma=scale, kernel=rbf;, score=0.390 total time=24.6min
# [CV 2/5] END ...........gamma=scale, kernel=rbf;, score=0.394 total time=24.7min
# [CV 3/5] END ...........gamma=scale, kernel=rbf;, score=0.388 total time=24.7min
# [CV 4/5] END ...........gamma=scale, kernel=rbf;, score=0.392 total time=24.7min
# [CV 5/5] END ...........gamma=scale, kernel=rbf;, score=0.389 total time=24.7min
# [CV 1/5] END ............gamma=auto, kernel=rbf;, score=0.391 total time=24.6min
# [CV 2/5] END ............gamma=auto, kernel=rbf;, score=0.394 total time=24.6min
# [CV 3/5] END ............gamma=auto, kernel=rbf;, score=0.388 total time=24.6min
# [CV 4/5] END ............gamma=auto, kernel=rbf;, score=0.392 total time=24.8min
# [CV 5/5] END ............gamma=auto, kernel=rbf;, score=0.389 total time=24.5min
# {'gamma': 'auto', 'kernel': 'rbf'}
# precision 0.39761485580147554

# %%
import pickle 

with open(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\freq_all_std_force_quality\SVM_freq.pickle', 'wb') as f:
    pickle.dump(model, f)
