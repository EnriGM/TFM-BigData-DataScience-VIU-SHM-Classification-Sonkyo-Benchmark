# %%
import numpy as np

x = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\x_for_ltsm.npy")
y = np.load(
    r"C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\res\freq_data_1_sec_force_quality_plus_t\y_for_ltsm.npy")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
SEED = 42

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

signal_x_train = x_train[:, :-1]
signal_x_test = x_test[:, :-1]
temp_x_train = x_train[:, -1].reshape(-1, 1)
temp_x_test = x_test[:, -1].reshape(-1, 1)

sc_temp = StandardScaler()
temp_x_train = sc_temp.fit_transform(temp_x_train)
temp_x_test = sc_temp.transform(temp_x_test)

sc = StandardScaler()
train_shape = signal_x_train.shape

signal_x_train = signal_x_train.reshape(train_shape[0]*train_shape[1])
signal_x_train = sc.fit_transform(signal_x_train.reshape(-1, 1))
signal_x_train = signal_x_train.reshape(train_shape[0], train_shape[1])

test_shape = signal_x_test.shape
signal_x_test = signal_x_test.reshape(test_shape[0]*test_shape[1])
signal_x_test = sc.transform(signal_x_test.reshape(-1, 1))
signal_x_test = signal_x_test.reshape(test_shape[0], test_shape[1])

# %%
import tensorflow as tf
from tensorflow import keras


time_input = keras.layers.Input(shape=(129, 1))
temp_input = keras.layers.Input(shape=(1,))

conv_1 = keras.layers.Conv1D(filters=32, kernel_size=32, strides=2, activation='relu')(time_input)

conv_3 = keras.layers.Conv1D(filters=64, kernel_size=16, strides=2, activation='relu')(conv_1)

conv_4 = keras.layers.Conv1D(filters=128, kernel_size=8, strides=2, activation='relu')(conv_3)

flat = keras.layers.Flatten()(conv_4)

dense0 = keras.layers.Dense(1, activation="relu")(temp_input)

merged = keras.layers.Concatenate(axis=1)([flat, dense0])

dense_1 = keras.layers.Dense(128, activation='relu')(merged)
dense_2 = keras.layers.Dense(64, activation='relu')(dense_1)
output = keras.layers.Dense(13, activation='softmax')(dense_2)

model = keras.models.Model(inputs=[time_input, temp_input], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 129, 1)]     0           []
#
#  conv1d (Conv1D)                (None, 49, 32)       1056        ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 17, 64)       32832       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 5, 128)       65664       ['conv1d_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  flatten (Flatten)              (None, 640)          0           ['conv1d_2[0][0]']
#
#  dense (Dense)                  (None, 1)            2           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 641)          0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          82176       ['concatenate[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 13)           845         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 190,831
# Trainable params: 190,831
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = keras.optimizers.Adam(
    learning_rate=learning_rate,
)
# Compile the model.
model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="acc")
    ],
)

# %%
batch_size = 128
num_epochs = 500

# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1)
# Fit the model.

history = model.fit(
    x=[signal_x_train, temp_x_train],
    y=y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=0.2,
    callbacks=[early_stopping, reduce_lr],
    verbose=2,
)
# Out:
# Epoch 1/500
# 1193/1193 - 9s - loss: 0.8279 - acc: 0.7135 - val_loss: 0.4783 - val_acc: 0.8255 - lr: 1.0000e-04 - 9s/epoch - 8ms/step
# Epoch 2/500
# 1193/1193 - 5s - loss: 0.3879 - acc: 0.8573 - val_loss: 0.3207 - val_acc: 0.8835 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 3/500
# 1193/1193 - 6s - loss: 0.2956 - acc: 0.8917 - val_loss: 0.2738 - val_acc: 0.8989 - lr: 1.0000e-04 - 6s/epoch - 5ms/step
# Epoch 4/500
# 1193/1193 - 5s - loss: 0.2513 - acc: 0.9069 - val_loss: 0.2331 - val_acc: 0.9139 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 5/500
# 1193/1193 - 5s - loss: 0.2229 - acc: 0.9181 - val_loss: 0.2218 - val_acc: 0.9176 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 6/500
# 1193/1193 - 5s - loss: 0.2028 - acc: 0.9252 - val_loss: 0.1913 - val_acc: 0.9305 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 7/500
# 1193/1193 - 5s - loss: 0.1862 - acc: 0.9319 - val_loss: 0.1843 - val_acc: 0.9320 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 8/500
# 1193/1193 - 5s - loss: 0.1732 - acc: 0.9369 - val_loss: 0.1694 - val_acc: 0.9383 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 9/500
# 1193/1193 - 5s - loss: 0.1633 - acc: 0.9401 - val_loss: 0.1544 - val_acc: 0.9440 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 10/500
# 1193/1193 - 5s - loss: 0.1541 - acc: 0.9438 - val_loss: 0.1530 - val_acc: 0.9449 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 11/500
# 1193/1193 - 5s - loss: 0.1472 - acc: 0.9465 - val_loss: 0.1455 - val_acc: 0.9483 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 12/500
# 1193/1193 - 5s - loss: 0.1381 - acc: 0.9501 - val_loss: 0.1353 - val_acc: 0.9509 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 13/500
# 1193/1193 - 5s - loss: 0.1321 - acc: 0.9519 - val_loss: 0.1350 - val_acc: 0.9506 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 14/500
# 1193/1193 - 5s - loss: 0.1256 - acc: 0.9540 - val_loss: 0.1247 - val_acc: 0.9559 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 15/500
# 1193/1193 - 5s - loss: 0.1220 - acc: 0.9556 - val_loss: 0.1262 - val_acc: 0.9544 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 16/500
# 1193/1193 - 5s - loss: 0.1165 - acc: 0.9579 - val_loss: 0.1235 - val_acc: 0.9554 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 17/500
# 1193/1193 - 5s - loss: 0.1114 - acc: 0.9596 - val_loss: 0.1203 - val_acc: 0.9548 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 18/500
# 1193/1193 - 6s - loss: 0.1070 - acc: 0.9613 - val_loss: 0.1067 - val_acc: 0.9611 - lr: 1.0000e-04 - 6s/epoch - 5ms/step
# Epoch 19/500
# 1193/1193 - 5s - loss: 0.1029 - acc: 0.9630 - val_loss: 0.1140 - val_acc: 0.9587 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 20/500
# 1193/1193 - 5s - loss: 0.1005 - acc: 0.9636 - val_loss: 0.0990 - val_acc: 0.9645 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 21/500
# 1193/1193 - 5s - loss: 0.0963 - acc: 0.9656 - val_loss: 0.0986 - val_acc: 0.9641 - lr: 1.0000e-04 - 5s/epoch - 4ms/step
# Epoch 22/500
# 1193/1193 - 5s - loss: 0.0934 - acc: 0.9661 - val_loss: 0.1077 - val_acc: 0.9617 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 23/500
# 1193/1193 - 5s - loss: 0.0904 - acc: 0.9672 - val_loss: 0.1011 - val_acc: 0.9630 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 24/500
# 1193/1193 - 5s - loss: 0.0880 - acc: 0.9682 - val_loss: 0.0928 - val_acc: 0.9663 - lr: 1.0000e-04 - 5s/epoch - 4ms/step
# Epoch 25/500
# 1193/1193 - 5s - loss: 0.0858 - acc: 0.9689 - val_loss: 0.0898 - val_acc: 0.9682 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 26/500
# 1193/1193 - 5s - loss: 0.0827 - acc: 0.9700 - val_loss: 0.0912 - val_acc: 0.9673 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 27/500
# 1193/1193 - 5s - loss: 0.0810 - acc: 0.9707 - val_loss: 0.1031 - val_acc: 0.9626 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 28/500
# 1193/1193 - 5s - loss: 0.0790 - acc: 0.9713 - val_loss: 0.0888 - val_acc: 0.9674 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 29/500
# 1193/1193 - 5s - loss: 0.0768 - acc: 0.9724 - val_loss: 0.0863 - val_acc: 0.9683 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 30/500
# 1193/1193 - 5s - loss: 0.0747 - acc: 0.9727 - val_loss: 0.0967 - val_acc: 0.9645 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 31/500
# 1193/1193 - 5s - loss: 0.0730 - acc: 0.9736 - val_loss: 0.0822 - val_acc: 0.9717 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 32/500
# 1193/1193 - 5s - loss: 0.0712 - acc: 0.9743 - val_loss: 0.0873 - val_acc: 0.9691 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 33/500
# 1193/1193 - 5s - loss: 0.0700 - acc: 0.9748 - val_loss: 0.0812 - val_acc: 0.9697 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 34/500
# 1193/1193 - 5s - loss: 0.0689 - acc: 0.9752 - val_loss: 0.0775 - val_acc: 0.9725 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 35/500
# 1193/1193 - 5s - loss: 0.0677 - acc: 0.9754 - val_loss: 0.0830 - val_acc: 0.9698 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 36/500
# 1193/1193 - 5s - loss: 0.0659 - acc: 0.9759 - val_loss: 0.0770 - val_acc: 0.9717 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 37/500
# 1193/1193 - 5s - loss: 0.0648 - acc: 0.9763 - val_loss: 0.0784 - val_acc: 0.9715 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 38/500
# 1193/1193 - 5s - loss: 0.0634 - acc: 0.9768 - val_loss: 0.0799 - val_acc: 0.9708 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 39/500
# 1193/1193 - 5s - loss: 0.0615 - acc: 0.9776 - val_loss: 0.0866 - val_acc: 0.9681 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 40/500
# 1193/1193 - 5s - loss: 0.0605 - acc: 0.9778 - val_loss: 0.0780 - val_acc: 0.9718 - lr: 1.0000e-04 - 5s/epoch - 4ms/step
# Epoch 41/500
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1193/1193 - 5s - loss: 0.0596 - acc: 0.9783 - val_loss: 0.0809 - val_acc: 0.9701 - lr: 1.0000e-04 - 5s/epoch - 5ms/step
# Epoch 42/500
# 1193/1193 - 5s - loss: 0.0512 - acc: 0.9819 - val_loss: 0.0713 - val_acc: 0.9744 - lr: 5.0000e-05 - 5s/epoch - 4ms/step
# Epoch 43/500
# 1193/1193 - 5s - loss: 0.0505 - acc: 0.9822 - val_loss: 0.0715 - val_acc: 0.9735 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 44/500
# 1193/1193 - 5s - loss: 0.0493 - acc: 0.9829 - val_loss: 0.0683 - val_acc: 0.9750 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 45/500
# 1193/1193 - 5s - loss: 0.0491 - acc: 0.9829 - val_loss: 0.0674 - val_acc: 0.9758 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 46/500
# 1193/1193 - 5s - loss: 0.0480 - acc: 0.9831 - val_loss: 0.0689 - val_acc: 0.9755 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 47/500
# 1193/1193 - 5s - loss: 0.0471 - acc: 0.9835 - val_loss: 0.0718 - val_acc: 0.9733 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 48/500
# 1193/1193 - 5s - loss: 0.0465 - acc: 0.9833 - val_loss: 0.0666 - val_acc: 0.9759 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 49/500
# 1193/1193 - 5s - loss: 0.0460 - acc: 0.9836 - val_loss: 0.0659 - val_acc: 0.9765 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 50/500
# 1193/1193 - 5s - loss: 0.0455 - acc: 0.9840 - val_loss: 0.0662 - val_acc: 0.9766 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 51/500
# 1193/1193 - 5s - loss: 0.0447 - acc: 0.9841 - val_loss: 0.0691 - val_acc: 0.9762 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 52/500
# 1193/1193 - 6s - loss: 0.0442 - acc: 0.9844 - val_loss: 0.0683 - val_acc: 0.9761 - lr: 5.0000e-05 - 6s/epoch - 5ms/step
# Epoch 53/500
# 1193/1193 - 5s - loss: 0.0439 - acc: 0.9845 - val_loss: 0.0667 - val_acc: 0.9766 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 54/500
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1193/1193 - 5s - loss: 0.0428 - acc: 0.9849 - val_loss: 0.0665 - val_acc: 0.9767 - lr: 5.0000e-05 - 5s/epoch - 5ms/step
# Epoch 55/500
# 1193/1193 - 5s - loss: 0.0388 - acc: 0.9866 - val_loss: 0.0653 - val_acc: 0.9774 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 56/500
# 1193/1193 - 5s - loss: 0.0384 - acc: 0.9870 - val_loss: 0.0669 - val_acc: 0.9757 - lr: 2.5000e-05 - 5s/epoch - 4ms/step
# Epoch 57/500
# 1193/1193 - 5s - loss: 0.0379 - acc: 0.9871 - val_loss: 0.0722 - val_acc: 0.9738 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 58/500
# 1193/1193 - 6s - loss: 0.0379 - acc: 0.9870 - val_loss: 0.0666 - val_acc: 0.9761 - lr: 2.5000e-05 - 6s/epoch - 5ms/step
# Epoch 59/500
# 1193/1193 - 5s - loss: 0.0373 - acc: 0.9872 - val_loss: 0.0645 - val_acc: 0.9774 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 60/500
# 1193/1193 - 5s - loss: 0.0368 - acc: 0.9876 - val_loss: 0.0665 - val_acc: 0.9774 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 61/500
# 1193/1193 - 5s - loss: 0.0366 - acc: 0.9875 - val_loss: 0.0675 - val_acc: 0.9758 - lr: 2.5000e-05 - 5s/epoch - 4ms/step
# Epoch 62/500
# 1193/1193 - 5s - loss: 0.0366 - acc: 0.9874 - val_loss: 0.0660 - val_acc: 0.9766 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 63/500
# 1193/1193 - 5s - loss: 0.0359 - acc: 0.9875 - val_loss: 0.0631 - val_acc: 0.9778 - lr: 2.5000e-05 - 5s/epoch - 4ms/step
# Epoch 64/500
# 1193/1193 - 5s - loss: 0.0354 - acc: 0.9882 - val_loss: 0.0671 - val_acc: 0.9768 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 65/500
# 1193/1193 - 5s - loss: 0.0352 - acc: 0.9881 - val_loss: 0.0642 - val_acc: 0.9775 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 66/500
# 1193/1193 - 5s - loss: 0.0352 - acc: 0.9880 - val_loss: 0.0638 - val_acc: 0.9773 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 67/500
# 1193/1193 - 5s - loss: 0.0344 - acc: 0.9882 - val_loss: 0.0731 - val_acc: 0.9744 - lr: 2.5000e-05 - 5s/epoch - 4ms/step
# Epoch 68/500
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1193/1193 - 5s - loss: 0.0346 - acc: 0.9883 - val_loss: 0.0650 - val_acc: 0.9777 - lr: 2.5000e-05 - 5s/epoch - 5ms/step
# Epoch 69/500
# 1193/1193 - 5s - loss: 0.0323 - acc: 0.9892 - val_loss: 0.0633 - val_acc: 0.9782 - lr: 1.2500e-05 - 5s/epoch - 5ms/step
# Epoch 70/500
# 1193/1193 - 5s - loss: 0.0321 - acc: 0.9894 - val_loss: 0.0646 - val_acc: 0.9775 - lr: 1.2500e-05 - 5s/epoch - 5ms/step
# Epoch 71/500
# 1193/1193 - 5s - loss: 0.0318 - acc: 0.9896 - val_loss: 0.0634 - val_acc: 0.9775 - lr: 1.2500e-05 - 5s/epoch - 5ms/step
# Epoch 72/500
# 1193/1193 - 5s - loss: 0.0317 - acc: 0.9896 - val_loss: 0.0638 - val_acc: 0.9784 - lr: 1.2500e-05 - 5s/epoch - 5ms/step
# Epoch 73/500
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 1193/1193 - 5s - loss: 0.0315 - acc: 0.9896 - val_loss: 0.0632 - val_acc: 0.9782 - lr: 1.2500e-05 - 5s/epoch - 5ms/step

# %%
_, accuracy = model.evaluate([signal_x_test, temp_x_test], y_test)
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1491/1491 [==============================] - 4s 3ms/step - loss: 0.0636 - acc: 0.9774
# Test accuracy: 97.74%

# %%
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
import matplotlib.pyplot as plt
metric = "acc"
plt.figure()
plt.plot(history.history[metric], label="train")
plt.plot(history.history["val_" + metric], label="val")
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend()
plt.show()
plt.close()
# Out:
# Test accuracy: 97.74%

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 10))
y_pred = model.predict([signal_x_test, temp_x_test])
y_pred = np.argmax(y_pred, axis = 1)
np.set_printoptions(precision=2)
disp = ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=lb.inverse_transform(range(0, 13)),
    cmap=plt.cm.Blues,
    normalize="true",
    ax=ax
)
disp.ax_.set_title("CNN1D_freq_confusion_matrix")

plt.show()
# Out:
# 1491/1491 [==============================] - 3s 2ms/step

# %%
model.save(r'C:\Users\AndreaEnrique\Documents\TFM_MBID_VIU\models\freq_all_std_force_quality\Conv1D_freq.h5', save_format="h5")
